# %% [markdown]
# # Problem Set 108
#
# Complete the problems described below.
#
# Submit your work via email. A special email address has been setup for this purpose, and you can attach whatever files are appropriate to any mail sent to the address below. So I can tell which files below to whom, please **title all submitted files as**:
#
#     LASTNAME firstname.py
#
# Submit this file to the class file submission email:
#
#     SUBMITT.6g9n8dakvpw0bkft@u.box.com

# %%
from decodes.core import *
from decodes.io.jupyter_out import JupyterOut
out = JupyterOut.two_pi( )
from math import *
# Out:
# http://decod.es/	v0.2.3
# io loaded

# %% [markdown]
# ## The Raster Family

# %% [markdown]
# #### 108.01
#
# Here we construct a number of raster-ish objects.
#
# * A BoolField, which is then populated with random booleans
# * A ValueField, which is then populated with random numbers
# * An Image, which is then populated with random Colors
# * A VecField, which is then populated with random Vecs
#
# In constructing these objects, the following notes may assist you.
#
# * The addresses of an initalized raster are returned by the `rstr.addresses()` method.
# * The construction of a number of random values (such as booleans and Vecs) shown listed below.

# %%
a_random_bool = random.choice([True, False])
a_random_num = random.random()
a_random_vec = Vec.random()

#### START YOUR WORK HERE ####

bf = ???
for address in bf.addresses: 
    ???

vf = ???
for address in vf.addresses: 
    ???
    
img = ???
for address in img.addresses: 
    ???

vecf = ???
for address in vecf.addresses: 
    ???

#### END YOUR WORK HERE ####
    
for address in vecf.addresses:
    pt = vecf.get_cpt(address[0],address[1])
    vec = vecf.get(address[0],address[1])
    out.put(Segment(pt,vec))

out.draw()
out.clear()

# %% [markdown]
# ## Basis Managers

# %% [markdown]
# #### 108.02
#
# Here we define an Arc `arc_next` as one that joins up with and extends a given Arc in a smooth, "s"-like curve.
#
# To complete this exercise, follow this pseudocode:
#
# * A Point `spt` is defined as the endpoint of the given Arc.
# * A Point `ctr` is defined as a translation of `spt` by a Vec from the origin of the given Arc to its endpoint.
# * A Point `ept` is defined as result of rotating `spt` about a center point `ctr` and by the negative of `sweep_angle`.
# * A Vec `tan` is defined as the normal vector of the Plane given by evaluating the given arc at `t=0`. Use the `eval_pln()` method for this.
# * An Arc `arc_next` is constructed by using the `Arc.from_tan()` static method.
#
# ***Note that Arcs cannot be plotted here in Jupyter, so you'll need to work in another context to visualize your work.***

# %%
sweep_angle = random.random() * math.pi*1.5
arc_base = Arc(CS(Point.random()), 1.0, sweep_angle)

#### START YOUR WORK HERE ####

???

arc_next = ???

#### START YOUR WORK HERE ####

# %% [markdown]
# ## Point Managers

# %% [markdown]
# #### 108.03
#
# Two PLines `pl_a` and `pl_b` are given which, taken together, look like a moustache. While they join in the middle, the proceed in different directions (out from the origin).
#
# Construct a new PLine `pl_c` from the given PLines that proceeds in a consistent direction, from left to right in the plot below.

# %%
pl_a = PLine([Point(-t,math.sin(t)) for t in Interval.twopi()/20])
pl_b = PLine([Point(t,math.sin(t)) for t in Interval.twopi()/20])
pl_a.set_color(0.5)
pl_b.set_color(0.5)

#### START YOUR WORK HERE ####

???

#### END YOUR WORK HERE ####
pl_c.set_color(1,0,0)
out.put([pl_a,pl_b,pl_c])
out.draw()
out.clear()
# Out:
# <div style="width:560.0px; height:360.0px; box-shadow: 2px 2px 8px 4px #ddd; margin: 8px;"><svg width="560.0" height="360.0" xmlns="http://www.w3.org/2000/svg" version="1.1">
# <polyline points="28.67258771281655,340.0 91.50444078461243,340.0 91.50444078461243,300.0 28.67258771281655,300.0 28.67258771281655,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# <polyline points="91.50444078461243,340.0 154.33629385640828,340.0 154.33629385640828,300.0 91.50444078461243,300.0 91.50444078461243,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# <polyline points="154.33629385640828,340.0 217.16814692820412,340.0 217.16814692820412,300.0 154.33629385640828,300.0 154.33629385640828,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# ...

# %% [markdown]
# ## Polygon Meshes

# %% [markdown]
# #### 108.04
#
# Construct a Mesh that describes a tetrahedron with vertices at the corners of a unit cube, as shown below. A unit cube is centered on the origin, with edge lengths of 1.0.
#
# <img src="https://www.technologyuk.net/mathematics/geometry/images/geometry_0175.gif">
#
#
# ***Note that Meshes cannot be plotted here in Jupyter, so you'll need to work in another context to visualize your work.***

# %%
pa,pb,pc,pd = Point(-0.5,0.5,-0.5), Point(0.5,-0.5,-0.5), Point(-0.5,-0.5,0.5), Point(0.5,0.5,0.5)

#### START YOUR WORK HERE ####

???

#### END YOUR WORK HERE ####

out.put([pa,pb,pc,pd])
out.draw()
out.clear()
# Out:
# dump not completely successful, the following geometry was not written:
# 69 msh[4v,4f]
# <div style="width:560.0px; height:360.0px; box-shadow: 2px 2px 8px 4px #ddd; margin: 8px;"><svg width="560.0" height="360.0" xmlns="http://www.w3.org/2000/svg" version="1.1">
# <polyline points="28.67258771281655,340.0 91.50444078461243,340.0 91.50444078461243,300.0 28.67258771281655,300.0 28.67258771281655,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# <polyline points="91.50444078461243,340.0 154.33629385640828,340.0 154.33629385640828,300.0 91.50444078461243,300.0 91.50444078461243,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# <polyline points="154.33629385640828,340.0 217.16814692820412,340.0 217.16814692820412,300.0 154.33629385640828,300.0 154.33629385640828,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# ...
