# %% [markdown]
# # Problem Set 107
#
# Complete the problems described below.
#
# Submit your work via email. A special email address has been setup for this purpose, and you can attach whatever files are appropriate to any mail sent to the address below. So I can tell which files below to whom, please **title all submitted files as**:
#
#     LASTNAME firstname.py
#
# Submit this file to the class file submission email:
#
#     SUBMITT.6g9n8dakvpw0bkft@u.box.com

# %%
from decodes.core import *
from decodes.io.jupyter_out import JupyterOut
out = JupyterOut.two_pi( )
from math import *
# Out:
# http://decod.es/	v0.2.3
# io loaded

# %% [markdown]
# ## Introduction to Transformations and Intersections

# %% [markdown]
# #### 107.01
#
# A Point `pt_src` and a Segment `seg` are given at random locations on the plane. As disucssed in the introduction of Chapter 1.07, construct a transformation that mirrors the given point about the given segment. Name the resulting point `pt_tar`.

# %%
pt_src = Point.random()
seg = Segment( Point.random(), Point.random() )

#### START YOUR WORK HERE ####

???

#### END YOUR WORK HERE ####

pt_tar.set_color(1,0,0)
out.put([seg,pt_src,pt_tar])
out.draw()
out.clear()
# Out:
# <div style="width:560.0px; height:360.0px; box-shadow: 2px 2px 8px 4px #ddd; margin: 8px;"><svg width="560.0" height="360.0" xmlns="http://www.w3.org/2000/svg" version="1.1">
# <polyline points="28.67258771281655,340.0 91.50444078461243,340.0 91.50444078461243,300.0 28.67258771281655,300.0 28.67258771281655,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# <polyline points="91.50444078461243,340.0 154.33629385640828,340.0 154.33629385640828,300.0 91.50444078461243,300.0 91.50444078461243,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# <polyline points="154.33629385640828,340.0 217.16814692820412,340.0 217.16814692820412,300.0 154.33629385640828,300.0 154.33629385640828,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# ...

# %% [markdown]
# ## Transformation Mathematics

# %% [markdown]
# #### 107.02
#
# The same two transformations are shown in each of the diagrams below: a mirror about the y-axis of world space, and a rotation about the origin at an angle of `math.pi/4`. As these diagrams show us, the order in which transformations are applied matters.
#
# In the space provided below, construct these transformations as `xf_a` for the mirror and `xf_b` for the rotation. Next, apply each of these transformations to the given PLines `shape_src_ab` and `shape_src_ba` in different sequences to produce different results. Name these results `shape_tar_ab` and `shape_tar_ba`.
#
# <img src="http://geometric-computation-images.s3-website-us-east-1.amazonaws.com/1.09.P14.jpg" style="width: 200px; display: inline;"><img src="http://geometric-computation-images.s3-website-us-east-1.amazonaws.com/1.09.P15.jpg" style="width: 200px; display: inline;">

# %%
shape = PLine( [Point(2,1), Point(3,1), Point(3,2), Point(2,2)] )
shape.set_fill(0)
out.put(shape)
shape_src_ab, shape_src_ba = PLine( shape.pts ), PLine( shape.pts )

#### START YOUR WORK HERE ####

???

#### END YOUR WORK HERE ####

shape_tar_ab.set_fill(1,0,0)
shape_tar_ba.set_fill(0,1,0)
out.put([shape_tar_ab,shape_tar_ba])
out.draw()
out.clear()
# Out:
# <div style="width:560.0px; height:360.0px; box-shadow: 2px 2px 8px 4px #ddd; margin: 8px;"><svg width="560.0" height="360.0" xmlns="http://www.w3.org/2000/svg" version="1.1">
# <polyline points="28.67258771281655,340.0 91.50444078461243,340.0 91.50444078461243,300.0 28.67258771281655,300.0 28.67258771281655,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# <polyline points="91.50444078461243,340.0 154.33629385640828,340.0 154.33629385640828,300.0 91.50444078461243,300.0 91.50444078461243,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# <polyline points="154.33629385640828,340.0 217.16814692820412,340.0 217.16814692820412,300.0 154.33629385640828,300.0 154.33629385640828,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# ...

# %% [markdown]
# ## Transformations in Code

# %% [markdown]
# #### 107.03
#
# Here's a funny flower that looks like a logo for an oil company. Let's make lots of them.
#
# A PGon `shape` is given, along with a CS `cs_src`. For each of the given CSs in the list `cs_tars`, construct a change of basis transformation that maps objects from `cs_src` to the CS from `cs_tars`. Apply this transformation to the given PGon, and output the result.

# %%
shape = PGon([CS(2,2).eval_cyl(abs(math.sin(t*2+t))-math.sin(t)/2,-t) for t in Interval.twopi()/60])
shape.set_fill(0)
out.put(shape)

cs_src = CS(1,1)
cs_tars = [CS(Point.random(Interval(-0.5,0.5)), Vec.random(constrain2d=True)) for n in range(20)]

#### START YOUR WORK HERE ####

???

#### END YOUR WORK HERE ####

out.draw()
out.clear()
# Out:
# <div style="width:560.0px; height:360.0px; box-shadow: 2px 2px 8px 4px #ddd; margin: 8px;"><svg width="560.0" height="360.0" xmlns="http://www.w3.org/2000/svg" version="1.1">
# <polyline points="28.67258771281655,340.0 91.50444078461243,340.0 91.50444078461243,300.0 28.67258771281655,300.0 28.67258771281655,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# <polyline points="91.50444078461243,340.0 154.33629385640828,340.0 154.33629385640828,300.0 91.50444078461243,300.0 91.50444078461243,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# <polyline points="154.33629385640828,340.0 217.16814692820412,340.0 217.16814692820412,300.0 154.33629385640828,300.0 154.33629385640828,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# ...

# %% [markdown]
# ## Intersections

# %% [markdown]
# #### 107.04
#
# Two random Planes are given, `pln_a` and `pln_b`. Find the line that describes their intersection, and assign this line to the `line_of_intersection` variable. Employ a `if-else` structure to account for non-intersecting planes.

# %%
pa,pb,pc,pd = Point.random(), Point.random(), Point.random(), Point.random()
pln_a = Plane.from_pts(Point(0,0), pa, pb)
pln_b = Plane.from_pts(Point(0,0), pc, pd)
line_of_intersection = False

#### START YOUR WORK HERE ####

???

#### END YOUR WORK HERE ####

seg = Segment(line_of_intersection.eval(-100), line_of_intersection.eval(100))
pa.set_color(1,0,0)
pb.set_color(1,0,0)
out.put(seg)
out.put([pa,pb,pc,pd])
out.draw()
out.clear()
# Out:
# <div style="width:560.0px; height:360.0px; box-shadow: 2px 2px 8px 4px #ddd; margin: 8px;"><svg width="560.0" height="360.0" xmlns="http://www.w3.org/2000/svg" version="1.1">
# <polyline points="28.67258771281655,340.0 91.50444078461243,340.0 91.50444078461243,300.0 28.67258771281655,300.0 28.67258771281655,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# <polyline points="91.50444078461243,340.0 154.33629385640828,340.0 154.33629385640828,300.0 91.50444078461243,300.0 91.50444078461243,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# <polyline points="154.33629385640828,340.0 217.16814692820412,340.0 217.16814692820412,300.0 154.33629385640828,300.0 154.33629385640828,340.0" style="fill:rgb(249,249,249);stroke-width:1;stroke:rgb(255,255,255)"/>
# ...
